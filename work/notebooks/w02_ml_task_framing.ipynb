# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jitoo18/Flyrank-Capstone/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
#
#
# ## My Lane as an ML Task
#
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# This is mainly a **ranking and scoring** machine learning task. The goal is not simply to classify pages as "refresh" or "do not refresh", but to assign each page a priority score and rank pages from highest to lowest refresh priority.
#
# This ranking helps content teams decide which pages should be reviewed first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
#
#
#
# The target is whether a page is showing signs of decline.
#
# In the starter dataset, the proxy target is based on the **trend_direction** column. Pages labelled **"down"** are treated as declining pages that may need a content refresh.
#
# This label comes from an observed outcome in the dataset and is used as a practical proxy for refresh priority.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
#
#
#
# I will use **Precision@50** as the main success metric.
#
# Precision@50 measures how many of the top 50 pages recommended by the model are actually declining.
#
# This metric matches the real decision because content teams usually review only a limited number of pages, making the quality of the highest-ranked recommendations more important than overall accuracy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
#
#
# ## Unit of Analysis
#
# The unit of analysis is an **individual content page**.
#
# Each row in the dataset represents one page and includes observable features such as impressions, click-through rate (CTR), average search position, content age, and days since the last update.
#
# These features will be used to estimate the priority for content refresh.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


# !git clone https://github.com/Jitoo18/Flyrank-Capstone.git
# %cd Flyrank-Capstone

# import os
# print(os.getcwd())



import os

if not os.path.exists("Flyrank-Capstone"):
    # !git clone https://github.com/Jitoo18/Flyrank-Capstone.git

# %cd Flyrank-Capstone

import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

columns = [
    "content_type",
    "impressions_90d",
    "avg_position",
    "ctr",
    "content_age_days",
    "days_since_last_update",
    "trend_direction"
]

print("Dataset Shape:", df.shape)
print("\nOne row represents one content page.\n")

lane_df = df[df["impressions_90d"] > 0]

print("Pages in lane:", len(lane_df))

lane_df[columns].head()
# Out:
# Cloning into 'Flyrank-Capstone'...
# remote: Enumerating objects: 124, done.
# remote: Counting objects: 100% (124/124), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 124 (delta 38), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (124/124), 1.83 MiB | 5.76 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/Flyrank-Capstone/Flyrank-Capstone/Flyrank-Capstone
# Dataset Shape: (30000, 44)
#
# One row represents one content page.
#
# Pages in lane: 30000
#       content_type  impressions_90d  avg_position   ctr  content_age_days  \
# 0  keyword article             3803          10.6  0.76               187
# 1  keyword article            15320          20.3  0.05               445
# 2  keyword article            12581          36.5  0.09               141
# 3  keyword article            11751           6.2  0.49               463
# 4  keyword article            19140          44.0  0.13               263
#
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
#
#
# A fixed rule may only consider one or two signals, such as content age or impressions.
#
# However, page performance is influenced by several factors that interact with one another, including impressions, CTR, average position, content age, and update history.
#
# Machine learning can combine these signals to produce a more useful ranking than a simple rule while still supporting human decision-making. The recommendations are intended as decision support rather than proof of how search engines rank pages.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
