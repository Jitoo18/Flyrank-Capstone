# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Jitoo18/Flyrank-Capstone/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# # My Lane
#
# I chose the **Refresh / Content Opportunity Scoring** lane.
#
# The goal is to identify pages that are most likely to benefit from a content review or refresh. Instead of refreshing every page, this approach prioritizes pages based on observable search and content signals so that effort can be focused where it is likely to have the greatest impact.
#
# I selected this lane because it supports a practical content decision and aligns with the refresh pipeline introduced in the starter notebooks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
#
# # Research Question
#
# **Decision**
#
# Which pages should be reviewed first for content refresh?
#
# **Action**
#
# Create a ranked list of pages that should be prioritized for review.
#
# **Unit of analysis**
#
# Individual pages.
#
# **Cost of a wrong recommendation**
#
# If a page is incorrectly recommended for refresh, time and resources may be spent unnecessarily.
#
# If an important declining page is missed, potential traffic or engagement improvements may be delayed.
#
# **Why ML helps**
#
# Multiple signals such as impressions, CTR, content age, average position, and update history may interact in ways that are difficult to capture with a simple rule. Machine learning can help rank pages using these combined signals.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
#
#
#
# The starter dataset contains 30,000 pages.
#
# The correlation between search volume and impressions was approximately **0.001**, suggesting that search volume alone is not a strong indicator of page impressions in this dataset.
#
# Median content age also varied by trend direction. Pages labelled "down" had a median age of **216 days**, while "stable" pages had a median age of **300 days**, indicating that content age alone does not explain performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.



# !git clone https://github.com/Jitoo18/Flyrank-Capstone.git
# %cd Flyrank-Capstone

# import os
# print(os.getcwd())


import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))

corr = df["search_volume"].corr(df["impressions_90d"])
print(f"Correlation (search_volume vs impressions_90d): {corr:.3f}")

print("\nMedian content age by trend direction:")
print(df.groupby("trend_direction")["content_age_days"].median())
# Out:
# Rows: 30000
# Correlation (search_volume vs impressions_90d): 0.001
#
# Median content age by trend direction:
# trend_direction
# down      216.0
# flat      231.0
# new       279.0
# stable    300.0
# up        291.5
# Name: content_age_days, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
#
# The findings in this notebook are observational.
#
# They identify patterns within the internship dataset and should not be interpreted as evidence of causation or proof of how Google's ranking systems work.
#
# The goal is decision support rather than prediction of search engine behavior.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
